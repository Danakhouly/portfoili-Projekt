# %%
import pandas as pd
pd
# Out:
# <module 'pandas' from 'c:\\Users\\Trainee\\Documents\\Portfoili-Projekt\\.venv\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
print('Hello' \
'')
# Out:
# Hello
